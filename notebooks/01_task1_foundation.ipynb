# %%
# Import modules
import sys
import os

# Add the parent directory to sys.path so 'src' can be imported
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.utils import load_brent_data
from src.eda import (
    plot_price_over_time,
    print_summary_stats,
    calculate_log_returns,
    plot_log_returns,
    test_stationarity,
)

# %%
# Load data
df = load_brent_data("../data/BrentOilPrices_Updated.csv")
# Out:
# d:\week-10\brent-oil-change-point-analysis\src\utils.py:10: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
# EDA: Plot price
plot_price_over_time(df)

# %%
# Summary stats
print_summary_stats(df)
# Out:
# Summary Statistics for Brent Oil Price:
# count    9011.000000
# mean       48.420782
# std        32.860110
# min         9.100000
# 25%        19.050000
# 50%        38.570000
# 75%        70.090000
# max       143.950000
# Name: Price, dtype: float64

# %%
# Calculate log returns and plot
df_log = calculate_log_returns(df)
plot_log_returns(df_log)

# %%
# Test stationarity on log returns
test_stationarity(df_log['LogReturn'])
# Out:
# ADF Statistic: -16.4271
# p-value: 0.0000
# Critical Value 1%: -3.4311
# Critical Value 5%: -2.8619
# Critical Value 10%: -2.5669
# => The series is likely stationary.
